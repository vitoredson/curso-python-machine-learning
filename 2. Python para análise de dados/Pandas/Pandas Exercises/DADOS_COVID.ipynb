# %%
import pandas as pd

# %%
cvd = pd.read_csv('C:\\Users\\Vitor\\Desktop\\owid-covid-data.csv')

# %%
cvd.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# ...

# %%
cvd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19918 entries, 0 to 19917
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         19854 non-null  object
#  1   location                         19918 non-null  object
#  2   date                             19918 non-null  object
#  3   total_cases                      19918 non-null  int64
#  4   new_cases                        19918 non-null  int64
#  5   total_deaths                     19918 non-null  int64
#  6   new_deaths                       19918 non-null  int64
#  7   total_cases_per_million          19541 non-null  float64
#  8   new_cases_per_million            19541 non-null  float64
#  9   total_deaths_per_million         19541 non-null  float64
#  10  new_deaths_per_million           19541 non-null  float64
#  11  total_tests                      5287 non-null   float64
# ...

# %%
cvd[cvd['diabetes_prevalence']==cvd['diabetes_prevalence'].max()].head(1)#['location']#.head(1)
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 13407      NCL  New Caledonia  2020-03-21            2          2
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 13407             0           0                    7.005
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 13407                  7.005                       0.0  ...          9.954
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cvd_death_rate  \
# 13407          6.489             NaN              NaN             NaN
#
#        diabetes_prevalence  female_smokers male_smokers  \
# 13407                23.36             NaN          NaN
#
#        handwashing_facilities  hospital_beds_per_100k
# 13407                     NaN                     NaN
#
# [1 rows x 32 columns]
